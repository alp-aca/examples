# %% [markdown]
# # Running
#
# This notebook computes the running of the ALP couplings for the various benchmark models considered in our work <a href="#AlpacaPheno">[0]</a>.
#
# The matching between the scale $\Lambda \in [10^2, 10^8]\,\mathrm{GeV}$ and the scale $\mu = m_b$.

# %%
import alpaca
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12, 'text.usetex': True, 'font.family': 'serif', 'font.serif': 'Computer Modern Roman'})
import matplotlib.gridspec as gridspec

from alpaca.constants import mb
import json

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_QED_DFSZ = []
cuu_QED_DFSZ = []
cdd_QED_DFSZ = []
css_QED_DFSZ = []
ccc_QED_DFSZ = []
cbb_QED_DFSZ = []
cds_QED_DFSZ = []
cdb_QED_DFSZ = []
csb_QED_DFSZ = []
cuc_QED_DFSZ = []
couplings_QED_DFSZ = []

for L in Lambda:
    c = alpaca.uvmodels.QED_DFSZ.get_couplings({alpaca.uvmodels.beta: np.pi/4}, L).match_run(mb, 'VA_below')
    couplings_QED_DFSZ.append(c)
    cee_QED_DFSZ.append(c['ceA'][1,1])
    cuu_QED_DFSZ.append(c['cuA'][0,0])
    cdd_QED_DFSZ.append(c['cdA'][0,0])
    css_QED_DFSZ.append(c['cdA'][1,1])
    ccc_QED_DFSZ.append(c['cuA'][1,1])
    cbb_QED_DFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_QED_DFSZ.append(cr['cdL'][0,1])
    cdb_QED_DFSZ.append(cr['cdL'][0,2])
    csb_QED_DFSZ.append(cr['cdL'][1,2])
    cuc_QED_DFSZ.append(cr['cuL'][0,1])

with open("appA_running_results/QED_DFSZ.json", "w") as f:
    json.dump(couplings_QED_DFSZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/QED_DFSZ.json", "rt") as f:
    couplings_QED_DFSZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_QED_DFSZ = []
cuu_QED_DFSZ = []
cdd_QED_DFSZ = []
css_QED_DFSZ = []
ccc_QED_DFSZ = []
cbb_QED_DFSZ = []
cds_QED_DFSZ = []
cdb_QED_DFSZ = []
csb_QED_DFSZ = []
cuc_QED_DFSZ = []

for c in couplings_QED_DFSZ:
    cee_QED_DFSZ.append(c['ceA'][1,1])
    cuu_QED_DFSZ.append(c['cuA'][0,0])
    cdd_QED_DFSZ.append(c['cdA'][0,0])
    css_QED_DFSZ.append(c['cdA'][1,1])
    ccc_QED_DFSZ.append(c['cuA'][1,1])
    cbb_QED_DFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_QED_DFSZ.append(cr['cdL'][0,1])
    cdb_QED_DFSZ.append(cr['cdL'][0,2])
    csb_QED_DFSZ.append(cr['cdL'][1,2])
    cuc_QED_DFSZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_uDFSZ = []
cuu_uDFSZ = []
cdd_uDFSZ = []
css_uDFSZ = []
ccc_uDFSZ = []
cbb_uDFSZ = []
cds_uDFSZ = []
cdb_uDFSZ = []
csb_uDFSZ = []
cuc_uDFSZ = []
couplings_uDFSZ = []

for L in Lambda:
    c = alpaca.uvmodels.u_DFSZ.get_couplings({alpaca.uvmodels.beta: np.pi/4}, L).match_run(mb, 'VA_below')
    couplings_uDFSZ.append(c)
    cee_uDFSZ.append(c['ceA'][1,1])
    cuu_uDFSZ.append(c['cuA'][0,0])
    cdd_uDFSZ.append(c['cdA'][0,0])
    css_uDFSZ.append(c['cdA'][1,1])
    ccc_uDFSZ.append(c['cuA'][1,1])
    cbb_uDFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_uDFSZ.append(cr['cdL'][0,1])
    cdb_uDFSZ.append(cr['cdL'][0,2])
    csb_uDFSZ.append(cr['cdL'][1,2])
    cuc_uDFSZ.append(cr['cuL'][0,1])

with open("appA_running_results/uDFSZ.json", "w") as f:
    json.dump(couplings_uDFSZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/uDFSZ.json", "rt") as f:
    couplings_uDFSZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_uDFSZ = []
cuu_uDFSZ = []
cdd_uDFSZ = []
css_uDFSZ = []
ccc_uDFSZ = []
cbb_uDFSZ = []
cds_uDFSZ = []
cdb_uDFSZ = []
csb_uDFSZ = []
cuc_uDFSZ = []

for c in couplings_uDFSZ:
    cee_uDFSZ.append(c['ceA'][1,1])
    cuu_uDFSZ.append(c['cuA'][0,0])
    cdd_uDFSZ.append(c['cdA'][0,0])
    css_uDFSZ.append(c['cdA'][1,1])
    ccc_uDFSZ.append(c['cuA'][1,1])
    cbb_uDFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_uDFSZ.append(cr['cdL'][0,1])
    cdb_uDFSZ.append(cr['cdL'][0,2])
    csb_uDFSZ.append(cr['cdL'][1,2])
    cuc_uDFSZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_eDFSZ = []
cuu_eDFSZ = []
cdd_eDFSZ = []
css_eDFSZ = []
ccc_eDFSZ = []
cbb_eDFSZ = []
cds_eDFSZ = []
cdb_eDFSZ = []
csb_eDFSZ = []
cuc_eDFSZ = []
couplings_eDFSZ = []

for L in Lambda:
    c = alpaca.uvmodels.e_DFSZ.get_couplings({alpaca.uvmodels.beta: np.pi/4}, L).match_run(mb, 'VA_below')
    couplings_eDFSZ.append(c)
    cee_eDFSZ.append(c['ceA'][1,1])
    cuu_eDFSZ.append(c['cuA'][0,0])
    cdd_eDFSZ.append(c['cdA'][0,0])
    css_eDFSZ.append(c['cdA'][1,1])
    ccc_eDFSZ.append(c['cuA'][1,1])
    cbb_eDFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_eDFSZ.append(cr['cdL'][0,1])
    cdb_eDFSZ.append(cr['cdL'][0,2])
    csb_eDFSZ.append(cr['cdL'][1,2])
    cuc_eDFSZ.append(cr['cuL'][0,1])

with open("appA_running_results/eDFSZ.json", "w") as f:
    json.dump(couplings_eDFSZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/eDFSZ.json", "rt") as f:
    couplings_eDFSZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_eDFSZ = []
cuu_eDFSZ = []
cdd_eDFSZ = []
css_eDFSZ = []
ccc_eDFSZ = []
cbb_eDFSZ = []
cds_eDFSZ = []
cdb_eDFSZ = []
csb_eDFSZ = []
cuc_eDFSZ = []

for c in couplings_eDFSZ:
    cee_eDFSZ.append(c['ceA'][1,1])
    cuu_eDFSZ.append(c['cuA'][0,0])
    cdd_eDFSZ.append(c['cdA'][0,0])
    css_eDFSZ.append(c['cdA'][1,1])
    ccc_eDFSZ.append(c['cuA'][1,1])
    cbb_eDFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_eDFSZ.append(cr['cdL'][0,1])
    cdb_eDFSZ.append(cr['cdL'][0,2])
    csb_eDFSZ.append(cr['cdL'][1,2])
    cuc_eDFSZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_QKSVZ = []
cuu_QKSVZ = []
cdd_QKSVZ = []
css_QKSVZ = []
ccc_QKSVZ = []
cbb_QKSVZ = []
cds_QKSVZ = []
cdb_QKSVZ = []
csb_QKSVZ = []
cuc_QKSVZ = []
couplings_QKSVZ = []

for L in Lambda:
    c = alpaca.uvmodels.Q_KSVZ.get_couplings({alpaca.uvmodels.KSVZ_charge: -1/2}, L).match_run(mb, 'VA_below')
    couplings_QKSVZ.append(c)
    cee_QKSVZ.append(c['ceA'][1,1])
    cuu_QKSVZ.append(c['cuA'][0,0])
    cdd_QKSVZ.append(c['cdA'][0,0])
    css_QKSVZ.append(c['cdA'][1,1])
    ccc_QKSVZ.append(c['cuA'][1,1])
    cbb_QKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_QKSVZ.append(cr['cdL'][0,1])
    cdb_QKSVZ.append(cr['cdL'][0,2])
    csb_QKSVZ.append(cr['cdL'][1,2])
    cuc_QKSVZ.append(cr['cuL'][0,1])

with open("appA_running_results/QKSVZ.json", "w") as f:
    json.dump(couplings_QKSVZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/QKSVZ.json", "rt") as f:
    couplings_QKSVZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_QKSVZ = []
cuu_QKSVZ = []
cdd_QKSVZ = []
css_QKSVZ = []
ccc_QKSVZ = []
cbb_QKSVZ = []
cds_QKSVZ = []
cdb_QKSVZ = []
csb_QKSVZ = []
cuc_QKSVZ = []

for c in couplings_QKSVZ:
    cee_QKSVZ.append(c['ceA'][1,1])
    cuu_QKSVZ.append(c['cuA'][0,0])
    cdd_QKSVZ.append(c['cdA'][0,0])
    css_QKSVZ.append(c['cdA'][1,1])
    ccc_QKSVZ.append(c['cuA'][1,1])
    cbb_QKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_QKSVZ.append(cr['cdL'][0,1])
    cdb_QKSVZ.append(cr['cdL'][0,2])
    csb_QKSVZ.append(cr['cdL'][1,2])
    cuc_QKSVZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_YKSVZ = []
cuu_YKSVZ = []
cdd_YKSVZ = []
css_YKSVZ = []
ccc_YKSVZ = []
cbb_YKSVZ = []
cds_YKSVZ = []
cdb_YKSVZ = []
csb_YKSVZ = []
cuc_YKSVZ = []
couplings_YKSVZ = []

for L in Lambda:
    c = alpaca.uvmodels.Y_KSVZ.get_couplings({alpaca.uvmodels.KSVZ_charge: -1/2}, L).match_run(mb, 'VA_below')
    couplings_YKSVZ.append(c)
    cee_YKSVZ.append(c['ceA'][1,1])
    cuu_YKSVZ.append(c['cuA'][0,0])
    cdd_YKSVZ.append(c['cdA'][0,0])
    css_YKSVZ.append(c['cdA'][1,1])
    ccc_YKSVZ.append(c['cuA'][1,1])
    cbb_YKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_YKSVZ.append(cr['cdL'][0,1])
    cdb_YKSVZ.append(cr['cdL'][0,2])
    csb_YKSVZ.append(cr['cdL'][1,2])
    cuc_YKSVZ.append(cr['cuL'][0,1])

with open("appA_running_results/YKSVZ.json", "w") as f:
    json.dump(couplings_YKSVZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/YKSVZ.json", "rt") as f:
    couplings_YKSVZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_YKSVZ = []
cuu_YKSVZ = []
cdd_YKSVZ = []
css_YKSVZ = []
ccc_YKSVZ = []
cbb_YKSVZ = []
cds_YKSVZ = []
cdb_YKSVZ = []
csb_YKSVZ = []
cuc_YKSVZ = []

for c in couplings_YKSVZ:
    cee_YKSVZ.append(c['ceA'][1,1])
    cuu_YKSVZ.append(c['cuA'][0,0])
    cdd_YKSVZ.append(c['cdA'][0,0])
    css_YKSVZ.append(c['cdA'][1,1])
    ccc_YKSVZ.append(c['cuA'][1,1])
    cbb_YKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_YKSVZ.append(cr['cdL'][0,1])
    cdb_YKSVZ.append(cr['cdL'][0,2])
    csb_YKSVZ.append(cr['cdL'][1,2])
    cuc_YKSVZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_LKSVZ = []
cuu_LKSVZ = []
cdd_LKSVZ = []
css_LKSVZ = []
ccc_LKSVZ = []
cbb_LKSVZ = []
cds_LKSVZ = []
cdb_LKSVZ = []
csb_LKSVZ = []
cuc_LKSVZ = []
couplings_LKSVZ = []

for L in Lambda:
    c = alpaca.uvmodels.L_KSVZ.get_couplings({alpaca.uvmodels.KSVZ_charge: -1/2}, L).match_run(mb, 'VA_below')
    couplings_LKSVZ.append(c)
    cee_LKSVZ.append(c['ceA'][1,1])
    cuu_LKSVZ.append(c['cuA'][0,0])
    cdd_LKSVZ.append(c['cdA'][0,0])
    css_LKSVZ.append(c['cdA'][1,1])
    ccc_LKSVZ.append(c['cuA'][1,1])
    cbb_LKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_LKSVZ.append(cr['cdL'][0,1])
    cdb_LKSVZ.append(cr['cdL'][0,2])
    csb_LKSVZ.append(cr['cdL'][1,2])
    cuc_LKSVZ.append(cr['cuL'][0,1])

with open("appA_running_results/LKSVZ.json", "w") as f:
    json.dump(couplings_LKSVZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/LKSVZ.json", "rt") as f:
    couplings_LKSVZ = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_LKSVZ = []
cuu_LKSVZ = []
cdd_LKSVZ = []
css_LKSVZ = []
ccc_LKSVZ = []
cbb_LKSVZ = []
cds_LKSVZ = []
cdb_LKSVZ = []
csb_LKSVZ = []
cuc_LKSVZ = []

for c in couplings_LKSVZ:
    cee_LKSVZ.append(c['ceA'][1,1])
    cuu_LKSVZ.append(c['cuA'][0,0])
    cdd_LKSVZ.append(c['cdA'][0,0])
    css_LKSVZ.append(c['cdA'][1,1])
    ccc_LKSVZ.append(c['cuA'][1,1])
    cbb_LKSVZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_LKSVZ.append(cr['cdL'][0,1])
    cdb_LKSVZ.append(cr['cdL'][0,2])
    csb_LKSVZ.append(cr['cdL'][1,2])
    cuc_LKSVZ.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_top = []
cuu_top = []
cdd_top = []
css_top = []
ccc_top = []
cbb_top = []
cds_top = []
cdb_top = []
csb_top = []
cuc_top = []
couplings_top = []

for L in Lambda:
    c = alpaca.ALPcouplings({'cuR': np.diag([0,0,1])}, L, 'derivative_above').match_run(mb, 'VA_below')
    couplings_top.append(c)
    cee_top.append(c['ceA'][1,1])
    cuu_top.append(c['cuA'][0,0])
    cdd_top.append(c['cdA'][0,0])
    css_top.append(c['cdA'][1,1])
    ccc_top.append(c['cuA'][1,1])
    cbb_top.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_top.append(cr['cdL'][0,1])
    cdb_top.append(cr['cdL'][0,2])
    csb_top.append(cr['cdL'][1,2])
    cuc_top.append(cr['cuL'][0,1])

with open("appA_running_results/top.json", "w") as f:
    json.dump(couplings_top, f, cls=alpaca.ALPcouplingsEncoder)

# %%
with open("appA_running_results/top.json", "rt") as f:
    couplings_top = json.load(f, cls=alpaca.ALPcouplingsDecoder)

cee_top = []
cuu_top = []
cdd_top = []
css_top = []
ccc_top = []
cbb_top = []
cds_top = []
cdb_top = []
csb_top = []
cuc_top = []

for c in couplings_top:
    cee_top.append(c['ceA'][1,1])
    cuu_top.append(c['cuA'][0,0])
    cdd_top.append(c['cdA'][0,0])
    css_top.append(c['cdA'][1,1])
    ccc_top.append(c['cuA'][1,1])
    cbb_top.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_top.append(cr['cdL'][0,1])
    cdb_top.append(cr['cdL'][0,2])
    csb_top.append(cr['cdL'][1,2])
    cuc_top.append(cr['cuL'][0,1])

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_flaxion = []
cuu_flaxion = []
cdd_flaxion = []
css_flaxion = []
ccc_flaxion = []
cbb_flaxion = []
cds_flaxion = []
cdb_flaxion = []
csb_flaxion = []
cuc_flaxion = []
couplings_flaxion = []

for L in Lambda:
    c = alpaca.uvmodels.flaxion_benchmark.get_couplings(0.2, L).match_run(mb, 'VA_below')
    couplings_flaxion.append(c)
    cee_flaxion.append(c['ceA'][1,1])
    cuu_flaxion.append(c['cuA'][0,0])
    cdd_flaxion.append(c['cdA'][0,0])
    css_flaxion.append(c['cdA'][1,1])
    ccc_flaxion.append(c['cuA'][1,1])
    cbb_flaxion.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_flaxion.append(cr['cdL'][0,1])
    cdb_flaxion.append(cr['cdL'][0,2])
    csb_flaxion.append(cr['cdL'][1,2])
    cuc_flaxion.append(cr['cuL'][0,1])

with open("appA_running_results/flaxion.json", "w") as f:
    json.dump(couplings_flaxion, f, cls=alpaca.ALPcouplingsEncoder)

# %%
Lambda = np.logspace(2.01, 8, 100)

cee_nonunivDFSZ = []
cuu_nonunivDFSZ = []
cdd_nonunivDFSZ = []
css_nonunivDFSZ = []
ccc_nonunivDFSZ = []
cbb_nonunivDFSZ = []
cds_nonunivDFSZ = []
cdb_nonunivDFSZ = []
csb_nonunivDFSZ = []
cuc_nonunivDFSZ = []
couplings_nonunivDFSZ = []

for L in Lambda:
    c = alpaca.uvmodels.nonuniversal_DFSZ.get_couplings({alpaca.uvmodels.beta: np.arctan(10.0)}, L).match_run(mb, 'VA_below')
    couplings_nonunivDFSZ.append(c)
    cee_nonunivDFSZ.append(c['ceA'][1,1])
    cuu_nonunivDFSZ.append(c['cuA'][0,0])
    cdd_nonunivDFSZ.append(c['cdA'][0,0])
    css_nonunivDFSZ.append(c['cdA'][1,1])
    ccc_nonunivDFSZ.append(c['cuA'][1,1])
    cbb_nonunivDFSZ.append(c['cdA'][2,2])
    cr = c.translate('RL_below')
    cds_nonunivDFSZ.append(cr['cdL'][0,1])
    cdb_nonunivDFSZ.append(cr['cdL'][0,2])
    csb_nonunivDFSZ.append(cr['cdL'][1,2])
    cuc_nonunivDFSZ.append(cr['cuL'][0,1])

with open("appA_running_results/nonunivDFSZ.json", "w") as f:
    json.dump(couplings_nonunivDFSZ, f, cls=alpaca.ALPcouplingsEncoder)

# %%
Lambda = np.logspace(2.01, 8, 100)

plt.figure(figsize=(17/2.54, 22/2.54))
gs = gridspec.GridSpec(4, 2)
gs.update(hspace=0.0)

ax = plt.subplot(gs[0])
ax.loglog(Lambda, np.abs(cee_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cee_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cee_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cee_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cee_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cee_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cee_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cee_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cee_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{\mu\mu}^A(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[0,0].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[1])
ax.loglog(Lambda, np.abs(cuu_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cuu_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cuu_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cuu_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cuu_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cuu_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cuu_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cuu_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cuu_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{uu}^A(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[0,1].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[2])
ax.loglog(Lambda, np.abs(cdd_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cdd_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cdd_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cdd_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cdd_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cdd_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cdd_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cdd_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cdd_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{dd}^A(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[1,0].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[3])
ax.loglog(Lambda, np.abs(cbb_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cbb_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cbb_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cbb_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cbb_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cbb_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cbb_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cbb_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cbb_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{bb}^A(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[1,1].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[4])
ax.loglog(Lambda, np.abs(cds_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cds_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cds_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cds_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cds_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cds_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cds_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cds_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cds_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{ds}^L(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[2,0].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[5])
ax.loglog(Lambda, np.abs(cdb_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cdb_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cdb_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cdb_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cdb_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cdb_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cdb_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cdb_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cdb_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{db}^L(m_b)|$")
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])
ax.set_xticklabels([])
ax.tick_params(axis='x', direction='in')
#ax[2,1].set_xlabel(r"$\Lambda$ [GeV]")

ax = plt.subplot(gs[6])
ax.loglog(Lambda, np.abs(csb_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(csb_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(csb_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(csb_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(csb_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(csb_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(csb_top), c='lightslategray')
ax.loglog(Lambda, np.abs(csb_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(csb_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{sb}^L(m_b)|$")
ax.set_xlabel(r"$\Lambda$ [GeV]")
ax.tick_params(axis='x', direction='inout')
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])

ax = plt.subplot(gs[7])
ax.loglog(Lambda, np.abs(cuc_QED_DFSZ), c='orangered')
ax.loglog(Lambda, np.abs(cuc_uDFSZ), c='darkred')
ax.loglog(Lambda, np.abs(cuc_eDFSZ), c='goldenrod')
ax.loglog(Lambda, np.abs(cuc_QKSVZ), c='darkgreen')
ax.loglog(Lambda, np.abs(cuc_YKSVZ), c='darkblue')
ax.loglog(Lambda, np.abs(cuc_LKSVZ), c='mediumturquoise')
ax.loglog(Lambda, np.abs(cuc_top), c='lightslategray')
ax.loglog(Lambda, np.abs(cuc_flaxion), c='orchid')
ax.loglog(Lambda, np.abs(cuc_nonunivDFSZ), c='yellowgreen')
ax.set_ylim(1e-9, 10)
ax.set_xlim(1e2, 1e8)
ax.set_ylabel(r"$|c_{uc}^L(m_b)|$")
ax.set_xlabel(r"$\Lambda$ [GeV]")
ax.tick_params(axis='x', direction='inout')
ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1])

#plt.subplots_adjust(hspace=0)
plt.tight_layout()
plt.savefig('appA_running_results/running_couplings.pdf', dpi=500)

# %% [markdown]
# ## References

# %% [markdown]
# <a id="AlpacaPheno">[0]</a>
# J. Alda, M. Fuentes Zamoro, L. Merlo, X. Ponce Diaz, S. Rigolin
# *Comprehensive ALP searches in Meson Decays*,
# In preparation.
